# %%
import numpy as np
import matplotlib.pyplot as plt

    
x = np.linspace(1, 20, 10)
plt.plot(x, 1 *  np. exp(-1*x) )
di = np.random.uniform(0, 20, 10)
plt.hist(di, bins = 20, density = True)
plt.show()
